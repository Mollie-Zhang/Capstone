# %%
import pandas as pd

# %%
# List of 12 monthly dataset filenames
dataset_filenames = [
    '202101.CSV',
    '202102.CSV',
    '202103.CSV',
    '202104.CSV',
    '202105.CSV',
    '202106.CSV',
    '202107.CSV',
    '202108.CSV',
    '202109.CSV',
    '202110.CSV',
    '202111.CSV',
    '202112.CSV'
]

# %%
# List to store the monthly dataframes
monthly_dataframes = []

# %%
# Iterate over each dataset filename
for filename in dataset_filenames:
    # Open the monthly dataset
    dataset = pd.read_csv(filename)
    
    # Drop the original headers in the dataset, use the first row as the new headers
    dataset = dataset.rename(columns=dataset.iloc[0]).drop(dataset.index[0]).reset_index(drop=True)
    
    # Drop the last row ('END OF REPORT') in the dataset
    dataset = dataset.iloc[:-1]
    
    # Drop the last 3 columns in the dataset
    dataset = dataset.iloc[:, :-3]
    
    # Drop the 1st, 2nd, 3rd, and 4th columns
    dataset = dataset.iloc[:, 4:]
    
    # Change SCADAVALUE to numeric
    dataset['SCADAVALUE'] = pd.to_numeric(dataset['SCADAVALUE'], errors='coerce')
    
    # Change SETTLEMENTDATE to datetime
    dataset['SETTLEMENTDATE'] = pd.to_datetime(dataset['SETTLEMENTDATE'])
    
    # Add a new column 'Month'
    dataset['Month'] = int(filename[4:6])  # Extract the month from the filename
    
    # Append the monthly dataset to the list
    monthly_dataframes.append(dataset)
# Out:
# /var/folders/d8/h7w8mcz55l74_qkxt5cw6j4r0000gn/T/ipykernel_1787/2365673500.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv(filename)
# /var/folders/d8/h7w8mcz55l74_qkxt5cw6j4r0000gn/T/ipykernel_1787/2365673500.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv(filename)
# /var/folders/d8/h7w8mcz55l74_qkxt5cw6j4r0000gn/T/ipykernel_1787/2365673500.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv(filename)
# /var/folders/d8/h7w8mcz55l74_qkxt5cw6j4r0000gn/T/ipykernel_1787/2365673500.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv(filename)
# /var/folders/d8/h7w8mcz55l74_qkxt5cw6j4r0000gn/T/ipykernel_1787/2365673500.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv(filename)
# /var/folders/d8/h7w8mcz55l74_qkxt5cw6j4r0000gn/T/ipykernel_1787/2365673500.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv(filename)
# /var/folders/d8/h7w8mcz55l74_qkxt5cw6j4r0000gn/T/ipykernel_1787/2365673500.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv(filename)
# /var/folders/d8/h7w8mcz55l74_qkxt5cw6j4r0000gn/T/ipykernel_1787/2365673500.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv(filename)
# /var/folders/d8/h7w8mcz55l74_qkxt5cw6j4r0000gn/T/ipykernel_1787/2365673500.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv(filename)
# /var/folders/d8/h7w8mcz55l74_qkxt5cw6j4r0000gn/T/ipykernel_1787/2365673500.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv(filename)
# /var/folders/d8/h7w8mcz55l74_qkxt5cw6j4r0000gn/T/ipykernel_1787/2365673500.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv(filename)
# /var/folders/d8/h7w8mcz55l74_qkxt5cw6j4r0000gn/T/ipykernel_1787/2365673500.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv(filename)

# %%
# Concatenate the monthly dataframes vertically to get the yearly electricity generation dataframe
yearly_df = pd.concat(monthly_dataframes, ignore_index=True)

yearly_df
# Out:
#               SETTLEMENTDATE      DUID  SCADAVALUE  Month
# 0        2021-01-01 00:55:00   BARCSF1    0.100000      1
# 1        2021-01-01 00:55:00  BUTLERSG    9.899999      1
# 2        2021-01-01 00:55:00  CALL_A_4    0.000000      1
# 3        2021-01-01 00:55:00  CAPTL_WF   31.332001      1
# 4        2021-01-01 00:55:00  CATHROCK   37.730000      1
# ...                      ...       ...         ...    ...
# 40161129 2022-01-01 00:00:00   YENDWF1   17.010000     12
# 40161130 2022-01-01 00:00:00     YWPS1  380.450620     12
# 40161131 2022-01-01 00:00:00     YWPS2    0.000000     12
# 40161132 2022-01-01 00:00:00     YWPS3  351.767090     12
# 40161133 2022-01-01 00:00:00     YWPS4  370.397460     12
#
# [40161134 rows x 4 columns]

# %%
# 2021 yearly elecrtricity generation aggragation by 'Month' and'DUID' 
# Group by 'Month' and 'DUID', and sum the 'SCADAVALUE' - i.e. the capacity of generator
aggregated_df = yearly_df.groupby(['Month', 'DUID'])['SCADAVALUE'].sum().reset_index()
aggregated_df
# Out:
#       Month     DUID    SCADAVALUE
# 0         1   AGLHAL  3.425169e+04
# 1         1   AGLSOM  9.407800e+03
# 2         1  ANGAST1  2.476500e+03
# 3         1    ARWF1  7.323133e+05
# 4         1   BALBG1  9.052110e+03
# ...     ...      ...           ...
# 4601     12    YSWF1  6.866740e+04
# 4602     12    YWPS1  2.127056e+06
# 4603     12    YWPS2  1.818258e+03
# 4604     12    YWPS3  2.583632e+06
# 4605     12    YWPS4  2.814195e+06
#
# [4606 rows x 3 columns]

# %%
aggregated_df.isnull().sum()
# Out:
# Month         0
# DUID          0
# SCADAVALUE    0
# dtype: int64

# %%
#Save the aggregated sheet as the yearly aggregated dataset
aggregated_df.to_csv('aggregatedDUID_2021.csv', index=False)

# %%
#Open the dataset of the generator information - 'Generators.csv'

file_generators = 'Generators.csv'

generators = pd.read_csv(file_generators)

generators
# Out:
#          DUID                                  Station Name Region  \
# 0     ADPBA1G                   Adelaide Desalination Plant     SA
# 1      ADPMH1                   Adelaide Desalination Plant     SA
# 2      ADPPV3                   Adelaide Desalination Plant     SA
# 3      ADPPV2                   Adelaide Desalination Plant     SA
# 4      ADPPV1                   Adelaide Desalination Plant     SA
# ..        ...                                           ...    ...
# 509     VBBL1                         Victorian Big Battery    VIC
# 510  WALGRVL1                              Wallgrove BESS 1    NSW
# 511   WANDBL1  Wandoan Battery Energy Storage System (BESS)    QLD
# 512     PUMP1                        Wivenhoe Power Station    QLD
# 513     PUMP2                        Wivenhoe Power Station    QLD
#
#     Dispatch Type Fuel Source - Primary Unit Size (MW)  Unnamed: 6  Unnamed: 7
# 0       Generator       Battery storage           5.45         NaN         NaN
# 1       Generator                 Hydro           0.72         NaN         NaN
# 2       Generator                 Solar           0.02         NaN         NaN
# 3       Generator                 Solar            0.1         NaN         NaN
# 4       Generator                 Solar           2.75         NaN         NaN
# ..            ...                   ...            ...         ...         ...
# 509          Load                                1.179         NaN         NaN
# 510          Load                   NaN          1.306         NaN         NaN
# 511          Load                   NaN           2.94         NaN         NaN
# 512          Load                     -            240         NaN         NaN
# 513          Load                     -            240         NaN         NaN
#
# [514 rows x 8 columns]

# %%
#Drop'Unnamed' columns with null values
generators.drop(generators.columns[6:8], axis=1, inplace=True)
generators
# Out:
#          DUID                                  Station Name Region  \
# 0     ADPBA1G                   Adelaide Desalination Plant     SA
# 1      ADPMH1                   Adelaide Desalination Plant     SA
# 2      ADPPV3                   Adelaide Desalination Plant     SA
# 3      ADPPV2                   Adelaide Desalination Plant     SA
# 4      ADPPV1                   Adelaide Desalination Plant     SA
# ..        ...                                           ...    ...
# 509     VBBL1                         Victorian Big Battery    VIC
# 510  WALGRVL1                              Wallgrove BESS 1    NSW
# 511   WANDBL1  Wandoan Battery Energy Storage System (BESS)    QLD
# 512     PUMP1                        Wivenhoe Power Station    QLD
# 513     PUMP2                        Wivenhoe Power Station    QLD
#
#     Dispatch Type Fuel Source - Primary Unit Size (MW)
# 0       Generator       Battery storage           5.45
# 1       Generator                 Hydro           0.72
# 2       Generator                 Solar           0.02
# 3       Generator                 Solar            0.1
# 4       Generator                 Solar           2.75
# ..            ...                   ...            ...
# 509          Load                                1.179
# 510          Load                   NaN          1.306
# 511          Load                   NaN           2.94
# 512          Load                     -            240
# 513          Load                     -            240
#
# [514 rows x 6 columns]

# %%
#Merge aggregated_df and generators using LEFT JOIN

merged_df = aggregated_df.merge(generators, on='DUID', how='left')
merged_df
# Out:
#       Month     DUID    SCADAVALUE                            Station Name  \
# 0         1   AGLHAL  3.425169e+04                   Hallett Power Station
# 1         1   AGLSOM  9.407800e+03                  Somerton Power Station
# 2         1  ANGAST1  2.476500e+03                  Angaston Power Station
# 3         1    ARWF1  7.323133e+05                        Ararat Wind Farm
# 4         1   BALBG1  9.052110e+03  Ballarat Battery Energy Storage System
# ...     ...      ...           ...                                     ...
# 4613     12    YSWF1  6.866740e+04                  Yaloak South Wind Farm
# 4614     12    YWPS1  2.127056e+06              Yallourn 'W' Power Station
# 4615     12    YWPS2  1.818258e+03              Yallourn 'W' Power Station
# 4616     12    YWPS3  2.583632e+06              Yallourn 'W' Power Station
# 4617     12    YWPS4  2.814195e+06              Yallourn 'W' Power Station
#
#      Region Dispatch Type Fuel Source - Primary Unit Size (MW)
# 0        SA     Generator                Fossil          228.6
# 1       VIC     Generator                Fossil           42.5
# 2        SA     Generator                Fossil          1.667
# 3       VIC     Generator                  Wind           9.03
# 4       VIC     Generator       Battery storage          1.764
# ...     ...           ...                   ...            ...
# 4613    VIC     Generator                  Wind           2.05
# 4614    VIC     Generator                Fossil            360
# 4615    VIC     Generator                Fossil            360
# 4616    VIC     Generator                Fossil            380
# 4617    VIC     Generator                Fossil            380
#
# [4618 rows x 8 columns]

# %%
merged_df.isnull().sum()
# Out:
# Month                      0
# DUID                       0
# SCADAVALUE                 0
# Station Name             484
# Region                   484
# Dispatch Type            484
# Fuel Source - Primary    505
# Unit Size (MW)           484
# dtype: int64

# %%
merged_df.head(20)
# Out:
#     Month      DUID     SCADAVALUE                            Station Name  \
# 0       1    AGLHAL   34251.685380                   Hallett Power Station
# 1       1    AGLSOM    9407.800030                  Somerton Power Station
# 2       1   ANGAST1    2476.500000                  Angaston Power Station
# 3       1     ARWF1  732313.271910                        Ararat Wind Farm
# 4       1    BALBG1    9052.110000  Ballarat Battery Energy Storage System
# 5       1    BALBL1   11716.080000  Ballarat Battery Energy Storage System
# 6       1  BALDHWF1  398483.220740                    Bald Hills Wind Farm
# 7       1  BANGOWF1     997.259100                     Bango 973 Wind Farm
# 8       1     BANN1  282794.782530                    Bannerton Solar Park
# 9       1  BARCALDN    1209.080000                Barcaldine Power Station
# 10      1   BARCSF1   35474.501217                   Barcaldine Solar Farm
# 11      1  BARKIPS1  156744.850120              Barker Inlet Power Station
# 12      1  BARRON-1  241637.480000              Barron Gorge Power Station
# 13      1  BARRON-2  232143.160000              Barron Gorge Power Station
# 14      1   BASTYAN   98189.976740                   Bastyan Power Station
# 15      1  BBTHREE1    1581.050000            Bell Bay Three Power Station
# 16      1  BBTHREE2    1832.700000            Bell Bay Three Power Station
# 17      1  BBTHREE3     595.110000            Bell Bay Three Power Station
# 18      1     BDL01    5030.160000                Bairnsdale Power Station
# 19      1     BDL02    7752.480000                Bairnsdale Power Station
#
#    Region Dispatch Type Fuel Source - Primary Unit Size (MW)
# 0      SA     Generator                Fossil          228.6
# 1     VIC     Generator                Fossil           42.5
# 2      SA     Generator                Fossil          1.667
# 3     VIC     Generator                  Wind           9.03
# 4     VIC     Generator       Battery storage          1.764
# 5     VIC          Load                     -          1.764
# 6     VIC     Generator                  Wind           2.05
# 7     NSW     Generator                  Wind           5.16
# 8     VIC     Generator                 Solar            2.5
# 9     QLD     Generator                Fossil             37
# 10    QLD     Generator                 Solar             10
# 11     SA     Generator                Fossil           17.5
# 12    QLD     Generator                 Hydro             30
# 13    QLD     Generator                 Hydro             30
# 14    TAS     Generator                 Hydro           79.9
# 15    TAS     Generator                Fossil             35
# 16    TAS     Generator                Fossil             35
# 17    TAS     Generator                Fossil             35
# 18    VIC     Generator                Fossil             47
# 19    VIC     Generator                Fossil             47

# %%
#Drop the rows of which the value in the 'SCADAVALUE' equals or is less than 0
#Drop the rows of which the value in the 'Dispatch Type' equals 'Load' - i.e. they are not generators

temp_df = merged_df[(merged_df['SCADAVALUE'] > 0) & (merged_df['Dispatch Type'] !='Load')]
temp_df
# Out:
#       Month     DUID    SCADAVALUE                            Station Name  \
# 0         1   AGLHAL  3.425169e+04                   Hallett Power Station
# 1         1   AGLSOM  9.407800e+03                  Somerton Power Station
# 2         1  ANGAST1  2.476500e+03                  Angaston Power Station
# 3         1    ARWF1  7.323133e+05                        Ararat Wind Farm
# 4         1   BALBG1  9.052110e+03  Ballarat Battery Energy Storage System
# ...     ...      ...           ...                                     ...
# 4613     12    YSWF1  6.866740e+04                  Yaloak South Wind Farm
# 4614     12    YWPS1  2.127056e+06              Yallourn 'W' Power Station
# 4615     12    YWPS2  1.818258e+03              Yallourn 'W' Power Station
# 4616     12    YWPS3  2.583632e+06              Yallourn 'W' Power Station
# 4617     12    YWPS4  2.814195e+06              Yallourn 'W' Power Station
#
#      Region Dispatch Type Fuel Source - Primary Unit Size (MW)
# 0        SA     Generator                Fossil          228.6
# 1       VIC     Generator                Fossil           42.5
# 2        SA     Generator                Fossil          1.667
# 3       VIC     Generator                  Wind           9.03
# 4       VIC     Generator       Battery storage          1.764
# ...     ...           ...                   ...            ...
# 4613    VIC     Generator                  Wind           2.05
# 4614    VIC     Generator                Fossil            360
# 4615    VIC     Generator                Fossil            360
# 4616    VIC     Generator                Fossil            380
# 4617    VIC     Generator                Fossil            380
#
# [3740 rows x 8 columns]

# %%
temp_df.isnull().sum()
# Out:
# Month                            0
# DUID                             0
# SCADAVALUE                       0
# Station Name                    67
# Region                          67
# Dispatch Type                   67
# Fuel Source - Primary           67
# Unit Size (MW)                  67
# Electricity Generation (MWh)     0
# dtype: int64

# %%
#Add a new column 'Electricity Generation(MWh)'
temp_df['Electricity Generation (MWh)'] = round(temp_df['SCADAVALUE'] * (5/60), 2)
temp_df
# Out:
# /var/folders/d8/h7w8mcz55l74_qkxt5cw6j4r0000gn/T/ipykernel_1787/3034994953.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['Electricity Generation (MWh)'] = round(temp_df['SCADAVALUE'] * (5/60), 2)
#       Month     DUID    SCADAVALUE                            Station Name  \
# 0         1   AGLHAL  3.425169e+04                   Hallett Power Station
# 1         1   AGLSOM  9.407800e+03                  Somerton Power Station
# 2         1  ANGAST1  2.476500e+03                  Angaston Power Station
# 3         1    ARWF1  7.323133e+05                        Ararat Wind Farm
# 4         1   BALBG1  9.052110e+03  Ballarat Battery Energy Storage System
# ...     ...      ...           ...                                     ...
# 4613     12    YSWF1  6.866740e+04                  Yaloak South Wind Farm
# 4614     12    YWPS1  2.127056e+06              Yallourn 'W' Power Station
# 4615     12    YWPS2  1.818258e+03              Yallourn 'W' Power Station
# 4616     12    YWPS3  2.583632e+06              Yallourn 'W' Power Station
# 4617     12    YWPS4  2.814195e+06              Yallourn 'W' Power Station
#
#      Region Dispatch Type Fuel Source - Primary Unit Size (MW)  \
# 0        SA     Generator                Fossil          228.6
# 1       VIC     Generator                Fossil           42.5
# 2        SA     Generator                Fossil          1.667
# 3       VIC     Generator                  Wind           9.03
# 4       VIC     Generator       Battery storage          1.764
# ...     ...           ...                   ...            ...
# 4613    VIC     Generator                  Wind           2.05
# 4614    VIC     Generator                Fossil            360
# 4615    VIC     Generator                Fossil            360
# 4616    VIC     Generator                Fossil            380
# 4617    VIC     Generator                Fossil            380
#
#       Electricity Generation (MWh)
# 0                          2854.31
# 1                           783.98
# 2                           206.38
# 3                         61026.11
# 4                           754.34
# ...                            ...
# 4613                       5722.28
# 4614                     177254.66
# 4615                        151.52
# 4616                     215302.66
# 4617                     234516.29
#
# [3740 rows x 9 columns]

# %%
temp_df.to_csv('temp_2021.csv', index=False)
